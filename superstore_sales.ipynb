# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("C:\\suyash_mishra\\IT_skills\\Infonexus_project\\superStore.xlsx")
df.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date  Shipping Days  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13              2
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07              2
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18              1
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30              2
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06              1
#
#       Ship Mode   Customer ID     Customer Name      Segment  Postal Code  \
# 0   First Class  AB-100151402     Aaron Bergman     Consumer      73120.0
# 1  Second Class     JR-162107     Justin Ritter    Corporate          NaN
# 2   First Class     CR-127307      Craig Reiter     Consumer          NaN
# 3   First Class    KM-1637548  Katherine Murray  Home Office          NaN
# 4      Same Day    RH-9495111       Rick Hansen     Consumer          NaN
#
#    ...                               Product Name    Sales Quantity Discount  \
# ...

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"], errors="coerce")
df["Ship Date"] = pd.to_datetime(df["Ship Date"], errors="coerce")

# %%
top_products = df.groupby("Product Name", as_index=False)["Sales"].sum().sort_values("Sales", ascending=False).head(5)
(top_products)
# Out:
#                         Product Name     Sales
# 302  Motorola Smart Phone, Full Size  48542.52
# 118     Cisco Smart Phone, Full Size  41325.20
# 10      Apple Smart Phone, Full Size  39334.46
# 311     Nokia Smart Phone, Full Size  27661.97
# 373    Samsung Smart Phone, Cordless  25438.59

# %%
category_sales = df.groupby("Category", as_index=False)["Sales"].sum().sort_values("Sales", ascending=False)
(category_sales)
# Out:
#           Category      Sales
# 2       Technology  727083.13
# 0        Furniture  581071.86
# 1  Office Supplies  339031.48

# %%
region_profit = df.groupby("Region", as_index=False)["Profit"].sum().sort_values("Profit", ascending=False)
(region_profit)
# Out:
#                Region    Profit
# 15      Southern Asia  35549.07
# 6        Eastern Asia  35202.70
# 11            Oceania  32775.49
# 20     Western Europe  28454.44
# 10    Northern Europe  22868.45
# 3     Central America  20929.83
# 16    Southern Europe  20425.68
# 7      Eastern Europe  12228.45
# 13  Southeastern Asia  10561.80
# 2      Central Africa   9375.42
# 12      South America   7723.58
# 9        North Africa   6848.10
# 4          Central US   5659.56
# 19       Western Asia   5120.87
# 1           Caribbean   4963.64
# 14    Southern Africa   4876.32
# 5      Eastern Africa   4302.72
# 8          Eastern US   2166.15
# 21         Western US   2114.03
# 17        Southern US   1350.59
# 18     Western Africa   1278.17
# 0              Canada    199.44

# %%
num_cols = df.select_dtypes(include="number").columns
corr = df[num_cols].corr()
(corr.round(2))
# Out:
#                Row ID  Shipping Days  Postal Code  Sales  Quantity  Discount  \
# Row ID           1.00           0.03         0.12  -0.12     -0.11     -0.02
# Shipping Days    0.03           1.00         0.09   0.24      0.10     -0.08
# Postal Code      0.12           0.09         1.00  -0.07     -0.12      0.08
# Sales           -0.12           0.24        -0.07   1.00      0.53     -0.16
# Quantity        -0.11           0.10        -0.12   0.53      1.00      0.05
# Discount        -0.02          -0.08         0.08  -0.16      0.05      1.00
# Profit           0.00           0.15        -0.08   0.52      0.13     -0.56
# Shipping Cost   -0.18          -0.25        -0.03   0.56      0.29     -0.12
# TotalSales      -0.09           0.21        -0.03   0.89      0.74     -0.08
# Dis_amt         -0.10          -0.01        -0.05   0.21      0.38      0.68
# Total           -0.09           0.22        -0.03   0.89      0.74     -0.08
#
# ...

# %%
# chart1

monthly_sales = df.groupby("YearMonth", as_index=False)["Sales"].sum().sort_values("YearMonth")

plt.figure(figsize=(10,4))
sns.lineplot(data=monthly_sales, x="YearMonth", y="Sales", marker="o")
plt.xticks(rotation=45)
plt.title("Monthly Sales Trend")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 3
#       1 # chart1
# ----> 3 monthly_sales = df.groupby("YearMonth", as_index=False)["Sales"].sum().sort_values("YearMonth")
#       5 plt.figure(figsize=(10,4))
#       6 sns.lineplot(data=monthly_sales, x="YearMonth", y="Sales", marker="o")
#
# File ~\anaconda3\Anconda2\Lib\site-packages\pandas\core\frame.py:8869, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8866 if level is None and by is None:
#    8867     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8869 return DataFrameGroupBy(
#    8870     obj=self,
#    8871     keys=by,
#    8872     axis=axis,
#    8873     level=level,
#    8874     as_index=as_index,
#    8875     sort=sort,
#    8876     group_keys=group_keys,
#    8877     observed=observed,
#    8878     dropna=dropna,
# ...
